# %% [markdown]
# # Create SRA submission sheet
# This Python Jupyter notebook creates a BioSample submission sheet for the Sequence Read Archive:
#
# First, import Python modules:

# %%
import datetime
import glob
import itertools
import os

import natsort

import pandas as pd

import yaml

# %% [markdown]
# Display full columns of data frames:

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Read the configuration for the uploads:

# %%
with open('upload_config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Read the Illumina runs to submit:

# %%
print(f"Reading Illumina runs from {config['barcode_runs']}")

illumina_runs = pd.read_csv(config['barcode_runs'])

print('Here are the first few entries in the Illumina runs:')
illumina_runs.head()
# Out:
# Reading Illumina runs from barcode_runs_Duke-NUS_antibodies.csv
# Here are the first few entries in the Illumina runs:
#      date    experiment library antibody  concentration concentration_units  \
# 0  211105  expt_135-139    lib1     none              0           ng_per_mL
# 1  211105  expt_135-139    lib2     none              0           ng_per_mL
# 2  211108  expt_140-148    lib1     none              0           ng_per_mL
# 3  211108  expt_140-148    lib2     none              0           ng_per_mL
# 4  211105      expt_135    lib1     mAb1            139           ng_per_mL
#
#        group  selection                         sample  frac_escape  \
# 0  Linfa_NUS  reference  expt_135-139-none-0-reference          NaN
# 1  Linfa_NUS  reference  expt_135-139-none-0-reference          NaN
# 2  Linfa_NUS  reference  expt_140-148-none-0-reference          NaN
# 3  Linfa_NUS  reference  expt_140-148-none-0-reference          NaN
# 4  Linfa_NUS     escape       expt_135-mAb1-139-escape        0.077
#
#    cells_sorted  \
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4      842165.0
#
#                                                                                                                 R1
# 0  /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt_135-9_lib1_ref*.fastq.gz
# 1  /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt_135-9_lib2_ref*.fastq.gz
# 2  /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt_140-8_lib1_ref*.fastq.gz
# 3  /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt_140-8_lib2_ref*.fastq.gz
# 4   /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt135_lib1_Abneg*.fastq.gz

# %% [markdown]
# Next make submission entries for the barcode runs, initially in "tidy" format with one FASTQ file per row:

# %%
submissions_tidy = (
    illumina_runs
    .assign(
        biosample_accession=lambda x: config['biosample_accession'],
        library_ID=lambda x: x['library'] + '_' + x['sample'],
        title=lambda x: 'SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for ' + x['sample'],
        library_strategy='AMPLICON',
        library_source='SYNTHETIC',
        library_selection='PCR',
        library_layout='single',
        platform='ILLUMINA',
        instrument_model='Illumina HiSeq 2500',
        design_description='PCR of barcodes from RBD variants',
        filetype='fastq',
        filename_fullpath=lambda x: x['R1'].str.split(';')
                                    .map(lambda flist: list(itertools.chain.from_iterable(glob.glob(f) for f in flist))),       
        )
    .explode('filename_fullpath')
    .assign(filename_fullpath=lambda x: x['filename_fullpath'].str.strip(),
            filename=lambda x: x['filename_fullpath'].map(os.path.basename))
    .drop(columns=illumina_runs.columns)
    .reset_index(drop=True)
    )

assert submissions_tidy['filename_fullpath'].map(os.path.isfile).all()

print('Here are the first few submission entries in tidy format:')
submissions_tidy.head()
# Out:
# Here are the first few submission entries in tidy format:
#   biosample_accession                          library_ID  \
# 0        SAMN27770976  lib1_expt_135-139-none-0-reference
# 1        SAMN27770976  lib1_expt_135-139-none-0-reference
# 2        SAMN27770976  lib1_expt_135-139-none-0-reference
# 3        SAMN27770976  lib1_expt_135-139-none-0-reference
# 4        SAMN27770976  lib2_expt_135-139-none-0-reference
#
#                                                                                            title  \
# 0  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_135-139-none-0-reference
# 1  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_135-139-none-0-reference
# 2  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_135-139-none-0-reference
# 3  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_135-139-none-0-reference
# 4  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_135-139-none-0-reference
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                                                                                            filename_fullpath  \
# 0  /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt_135-9_lib1_ref1_S1_R1_001.fastq.gz
# 1  /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt_135-9_lib1_ref3_S3_R1_001.fastq.gz
# 2  /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt_135-9_lib1_ref2_S2_R1_001.fastq.gz
# 3  /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt_135-9_lib1_ref4_S4_R1_001.fastq.gz
# 4  /shared/ngs/illumina/tstarr/211120_VH00319_112_AAAN3C2M5/Unaligned/Project_tstarr/expt_135-9_lib2_ref1_S5_R1_001.fastq.gz
#
#                                   filename
# 0  expt_135-9_lib1_ref1_S1_R1_001.fastq.gz
# 1  expt_135-9_lib1_ref3_S3_R1_001.fastq.gz
# 2  expt_135-9_lib1_ref2_S2_R1_001.fastq.gz
# 3  expt_135-9_lib1_ref4_S4_R1_001.fastq.gz
# 4  expt_135-9_lib2_ref1_S5_R1_001.fastq.gz

# %% [markdown]
# For the actual submission, we need a "wide" data frame that for each unique `sample_name` / `library_ID` gives all of the files each in different columns.
# These should be files without the full path.
#
# First, look at how many files there are for each sample / library:

# %%
(submissions_tidy
 .groupby(['biosample_accession', 'library_ID'])
 .aggregate(n_files=pd.NamedAgg('filename_fullpath', 'count'))
 .sort_values('n_files', ascending=False)
 .reset_index()
 )
# Out:
#    biosample_accession                          library_ID  n_files
# 0         SAMN27770976  lib1_expt_135-139-none-0-reference        4
# 1         SAMN27770976  lib1_expt_140-148-none-0-reference        4
# 2         SAMN27770976  lib2_expt_140-148-none-0-reference        4
# 3         SAMN27770976  lib2_expt_135-139-none-0-reference        4
# 4         SAMN27770976      lib1_expt_148-mAb14-256-escape        3
# 5         SAMN27770976       lib1_expt_138-mAb4-462-escape        1
# 6         SAMN27770976       lib2_expt_137-mAb3-234-escape        1
# 7         SAMN27770976      lib2_expt_147-mAb13-147-escape        1
# 8         SAMN27770976      lib2_expt_146-mAb12-267-escape        1
# 9         SAMN27770976      lib2_expt_145-mAb11-125-escape        1
# 10        SAMN27770976      lib2_expt_144-mAb10-147-escape        1
# 11        SAMN27770976       lib2_expt_143-mAb9-154-escape        1
# 12        SAMN27770976      lib2_expt_142-mAb8-2000-escape        1
# 13        SAMN27770976       lib2_expt_141-mAb7-103-escape        1
# 14        SAMN27770976       lib2_expt_140-mAb6-584-escape        1
# 15        SAMN27770976       lib1_expt_136-mAb2-232-escape        1
# 16        SAMN27770976      lib2_expt_139-mAb5-1694-escape        1
# 17        SAMN27770976       lib2_expt_138-mAb4-462-escape        1
# 18        SAMN27770976       lib2_expt_136-mAb2-232-escape        1
# 19        SAMN27770976      lib1_expt_139-mAb5-1694-escape        1
# 20        SAMN27770976       lib2_expt_135-mAb1-139-escape        1
# 21        SAMN27770976       lib1_expt_135-mAb1-139-escape        1
# 22        SAMN27770976      lib1_expt_147-mAb13-147-escape        1
# 23        SAMN27770976      lib1_expt_146-mAb12-267-escape        1
# 24        SAMN27770976      lib1_expt_145-mAb11-125-escape        1
# 25        SAMN27770976      lib1_expt_144-mAb10-147-escape        1
# 26        SAMN27770976       lib1_expt_143-mAb9-154-escape        1
# 27        SAMN27770976      lib1_expt_142-mAb8-2000-escape        1
# 28        SAMN27770976       lib1_expt_141-mAb7-103-escape        1
# 29        SAMN27770976       lib1_expt_140-mAb6-584-escape        1
# 30        SAMN27770976       lib1_expt_137-mAb3-234-escape        1
# 31        SAMN27770976      lib2_expt_148-mAb14-256-escape        1

# %% [markdown]
# Now make the wide submission data frame.
# Note we keep only the filename column with the path lacking the full directory information:

# %%
submissions_wide = (
    submissions_tidy
    .assign(
        filename_count=lambda x: x.groupby(['biosample_accession', 'library_ID'])['filename'].cumcount() + 1,
        filename_col=lambda x: 'filename' + x['filename_count'].map(lambda c: str(c) if c > 1 else '')
        )
    .pivot(
        index='library_ID',
        columns='filename_col',
        values='filename',
        )
    )

submissions_wide = (
    submissions_tidy
    .drop(columns=['filename_fullpath', 'filename'])
    .drop_duplicates()
    .merge(submissions_wide[natsort.natsorted(submissions_wide.columns)],
           on='library_ID',
           validate='one_to_one',
           )
    )

print('Here are the first few submission entries in wide format:')
submissions_wide.head()
# Out:
# Here are the first few submission entries in wide format:
#   biosample_accession                          library_ID  \
# 0        SAMN27770976  lib1_expt_135-139-none-0-reference
# 1        SAMN27770976  lib2_expt_135-139-none-0-reference
# 2        SAMN27770976  lib1_expt_140-148-none-0-reference
# 3        SAMN27770976  lib2_expt_140-148-none-0-reference
# 4        SAMN27770976       lib1_expt_135-mAb1-139-escape
#
#                                                                                            title  \
# 0  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_135-139-none-0-reference
# 1  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_135-139-none-0-reference
# 2  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_140-148-none-0-reference
# 3  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_140-148-none-0-reference
# 4       SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_135-mAb1-139-escape
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                    filename  \
# 0   expt_135-9_lib1_ref1_S1_R1_001.fastq.gz
# 1   expt_135-9_lib2_ref1_S5_R1_001.fastq.gz
# 2  expt_140-8_lib1_ref2_S20_R1_001.fastq.gz
# 3  expt_140-8_lib2_ref3_S25_R1_001.fastq.gz
# 4     expt135_lib1_Abneg_S9_R1_001.fastq.gz
#
#                                   filename2  \
# 0   expt_135-9_lib1_ref3_S3_R1_001.fastq.gz
# 1   expt_135-9_lib2_ref4_S8_R1_001.fastq.gz
# 2  expt_140-8_lib1_ref1_S19_R1_001.fastq.gz
# 3  expt_140-8_lib2_ref2_S24_R1_001.fastq.gz
# 4                                       NaN
#
#                                   filename3  \
# 0   expt_135-9_lib1_ref2_S2_R1_001.fastq.gz
# 1   expt_135-9_lib2_ref2_S6_R1_001.fastq.gz
# 2  expt_140-8_lib1_ref3_S21_R1_001.fastq.gz
# 3  expt_140-8_lib2_ref1_S23_R1_001.fastq.gz
# 4                                       NaN
#
#                                   filename4
# 0   expt_135-9_lib1_ref4_S4_R1_001.fastq.gz
# 1   expt_135-9_lib2_ref3_S7_R1_001.fastq.gz
# 2  expt_140-8_lib1_ref4_S22_R1_001.fastq.gz
# 3  expt_140-8_lib2_ref4_S26_R1_001.fastq.gz
# 4                                       NaN

# %% [markdown]
# Now write the wide submissions data frame to a `*.tsv` file that can be used for uploading the SRA submission website:

# %%
submissions_spreadsheet = 'SRA_submission_spreadsheet.tsv'

submissions_wide.to_csv(submissions_spreadsheet, sep='\t', index=False)

# %% [markdown]
# We also want to write a file with all of the FASTQ files that are in the submission spreadsheet:

# %%
fastq_file_list = 'FASTQs_to_upload.csv'

print(f"Writing list of all the FASTQ files to upload to {fastq_file_list}")

(submissions_tidy
 [['filename_fullpath', 'filename']]
 .to_csv(fastq_file_list, index=False)
 )
# Out:
# Writing list of all the FASTQ files to upload to FASTQs_to_upload.csv
